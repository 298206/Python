# %% [markdown]
# # OOP-python:
# - A method in which data and operations are modeled as paired rather than seprate elements.

# %% [markdown]
# # Class:
# - Class is blueprint of a design.
# - A group of object that shares commonality in their encoding and supported bahaviour as intimately paired rather than seprate elements.
# # Object:
# - An entity derived from class which typically represents some real world concept.
# # Instance:
# - A single object driven from the class.
# # Attribute:
# - One of the piece of data used in representing the state of an object.It is also called field,datamember or instance variable.
# # Method:
# - A formal operation supported by all objects of a given class.
# - A function defind inside the class is a method.

# %%
file=open("OOPfile.txt","w")#object

# %%
file.write("This is an OOP tutorial.")#method
# Out:
# 24

# %%
file.close()#method

# %%
file.closed#Attribute
# Out:
# True

# %% [markdown]
# # Everything in Python is Object:

# %% [markdown]
# ## Creating class in python:

# %%
class Person:
    pass

# %% [markdown]
# ## Creating object of a class:

# %%
x=Person()
y=Person()

# %%
print(id(x),id(y))
# Out:
# 2243754366816 2243754367872

# %% [markdown]
# ## Class variable:
# - A variable of class shared by all instances.

# %%
class Person:
    m='hello'

# %%
x=Person()
y=Person()

# %%
print(x.m)
print(y.m)
# Out:
# hello
# hello

# %%
Person.m
# Out:
# 'hello'

# %%
x.m
# Out:
# 'hello'

# %%
y.m
# Out:
# 'hello'

# %% [markdown]
# # Instance variable:

# %%
class person:
    pass

# %%
x.t=80

# %%
y.j=100

# %%
print(x.t)
# Out:
# 80

# %%
print(x.j)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7cb8b72b4766> in <module>
# ----> 1 print(x.j)
#
# AttributeError: 'Person' object has no attribute 'j'

# %%
person.mro
# Out:
# <function person.mro()>

# %%
y.t
# Out:
# 100

# %% [markdown]
# # Constructor Method:
# - These are the methods that are useful for any kind of intiallization one wants to perform with the object.
# - A constructor is excuted as soon as an object is instantated.

# %%
class Mynum:
    def __init__(self):
        print("Calling the init.")
        self.val=0
    def increment(self):
        self.val=self.val+1
        print(self.val)

# %%
x=Mynum()
# Out:
# Calling the init.

# %%
x.val
# Out:
# 0

# %%
x.increment()
# Out:
# 1

# %%
x.val
# Out:
# 1

# %% [markdown]
# # Example to demonstrate difference between abstraction and encapsulation:

# %%
class Enc:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def add(self):
        return self.a*self.b

# %%
Enc_object=Enc(3,4)

# %%
Enc_object.add()
# Out:
# 12

# %% [markdown]
# ## A complete example:

# %%
class Employee:
    empcount=0
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
        Employee.empcount+=1
    def displaycount(self):
        print(f"Total employee are {Employee.empcount}")
    def displayemployee(self):
        print(f"Name is {self.name} and salary is {self.salary}")
    def __str__(self):
        return f"The employee name is {self.name}"

# %%
p=Employee("Python",1000)

# %%
p.displaycount()
# Out:
# Total employee are 1

# %%
p.displayemployee()
# Out:
# Name is Python and salary is 1000

# %%
print(Employee.empcount)
# Out:
# 1

# %%
j=Employee("java",200)

# %%
j.displaycount()
# Out:
# Total employee are 2

# %%
j.displayemployee()
# Out:
# Name is java and salary is 200

# %%
print(Employee.empcount)
# Out:
# 2

# %%
print(j)
# Out:
# The employee name is java

# %% [markdown]
# ## Dunder Methods:
# ```
# __init__= constructor
# __str__= object representation
# __add_= operator overloading
# __sub__= operator overloading
# __len__= for iteration
# __eq__= for operator overloading
# __lt__= for o[peartor overloading
# __del__= destructor method
# ```

# %% [markdown]
# # Destrucot mathod:
# - The del method is known as destructor method in python.It is called when references to the object have been deleted i.e the object is garbage collector.

# %%
class Employee:
    def __init__(self):
        print("Employee created")
    def __del__(self):
        print("destructor called,employee deleted")

# %%
e=Employee()
# Out:
# Employee created
# destructor called,employee deleted

# %%
del e
# Out:
# destructor called,employee deleted

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-094e3afb2fe8> in <module>
# ----> 1 e
#
# NameError: name 'e' is not defined

# %% [markdown]
# # WAP to create class car. create two objects Maruti with red color and price to 10 lakhs and Kia with blue color and price 7 laks.

# %%
class Car:
    def __init__(self,color,price,name):
        self.color=color
        self.price=price
        self.name=name
    def __str__(self):
        return f"The car name  is {self.name} and color is {self.color} and price is {self.price}"

# %%
maruti=Car("red",1000000,"Maruti")

# %%
Kia=Car("blue",700000,"Kia")

# %%
print(maruti)
# Out:
# The car name  is Maruti and color is red and price is 1000000

# %%
print(Kia)
# Out:
# The car name  is Kia and color is blue and price is 700000

# %% [markdown]
#  # Write a Python class named Student with two attributes student_name, marks. Modify the attribute values of the said class and print the original and modified values of the said attributes

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def modified(self):
        self.name="Python"
        self.marks=100

# %%
s=Student('Riya',90)

# %%
s.name,s.marks
# Out:
# ('Riya', 90)

# %%
s.modified()

# %%
s.name,s.marks
# Out:
# ('Python', 100)

# %% [markdown]
# # Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle

# %%
class Rectangel:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        a=self.length*self.width
        print(f"Rectangle of area is {a}")

# %%
r=Rectangel(12,2)

# %%
r.area()
# Out:
# Rectangle of area is 24

# %% [markdown]
# # Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle.

# %%
import math
class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        p=2*math.pi*self.radius
        print(f"Rectangle of parameter {p}")
    def area1(self):
        a=math.pi*self.radius**2
        print(f"Rectangle of area {a}")

# %%
c=Circle(3)

# %%
c.area()
# Out:
# Rectangle of parameter 18.84955592153876

# %%
c.area1()
# Out:
# Rectangle of area 28.274333882308138

# %% [markdown]
#  # Write a python program to demonstrate the use of try-except-else in Exception handling.

# %%
try:
    print(Q)
except:
    print("Error occured.")
else:
    print("success.")
# Out:
# Error occured.

# %%
def fun():
    try:
        return 1
    except:
        return 2
    finally:
        return 3
fun()
# Out:
# 3

# %% [markdown]
# #  Write a python program to demonstrate the use of raise in Exception handling.

# %%
x=int(input("Enter the number: "))
if x<=5:
    raise RuntimeError("Enter value greater than 5.")
# Out:
# Enter the number: 4
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-2691b3b349f3> in <module>
#       1 x=int(input("Enter the number: "))
#       2 if x<=5:
# ----> 3     raise RuntimeError("Enter value greater than 5.")
#
# RuntimeError: Enter value greater than 5.

# %% [markdown]
# #  Write a python program to demonstrate the use of custom exceptions in Exception handling.

# %%
class Myerror(Exception):
    pass
class fiveerror(Myerror):
    pass
try:
    i=int(input("Enter number: "))
    if i==5:
        raise fiveerror
except fiveerror:
    print("enter number other than 5.")
# Out:
# Enter number: 5
# enter number other than 5.

# %%
i=5
if i==5:
    raise fiveerror
# Out:
# ---------------------------------------------------------------------------
# fiveerror                                 Traceback (most recent call last)
# <ipython-input-44-b2a6c21af3d7> in <module>
#       1 i=5
#       2 if i==5:
# ----> 3     raise fiveerror
#
# fiveerror:

# %%
i=5
if i==5:
    raise fiveerror("enter other than 5.")
# Out:
# ---------------------------------------------------------------------------
# fiveerror                                 Traceback (most recent call last)
# <ipython-input-45-d13e6bad5168> in <module>
#       1 i=5
#       2 if i==5:
# ----> 3     raise fiveerror("enter other than 5.")
#
# fiveerror: enter other than 5.

# %% [markdown]
#  ``` 541:   Bank Account class:
#  Create a Python class called BankAccount which represents a bank account,
#  having as attributes: accountNumber (numeric type), name
# (name of the account owner as string type), balance.
#  Create a constructor with parameters: accountNumber, name, balance.
#  Create a Deposit() method which manages the deposit actions.
#  Create a Withdrawal() method  which manages withdrawals actions.
#  Create a display() method to display account details.
#  Give the complete code for the  BankAccount class.
#  Create the object and call all methods of the  BankAccount  class
#  ```

# %%
class BankAccount:
    def __init__(self,ano,aname,balance):
        self.ano=ano
        self.aname=aname
        self.balance=balance
    def Deposit(self,balance):
        self.balance+=balance
    def Withdrawal(self,balance):
        if balance<=self.balance:
            self.balance=self.balance-balance
        else:
            print("Insufficient balance!!")
    def Display(self):
        print("Account name: ",self.aname)
        print("Account number: ",self.ano)
        print("Balance: ",self.balance)

# %%
b=BankAccount(123,"riya",25000.0)

# %%
b.Deposit(1000)

# %%
b.Withdrawal(2000)

# %%
b.Display()
# Out:
# Account name:  riya
# Account number:  123
# Balance:  23000.0

# %% [markdown]
#  You need to create a class called Atm. It should have methods to create the pin, to change the pin, to check balance, to
# withdraw money, to deposit money. Also, you need to create method called menu to choose from the above given
# operations which you want to perform.
# create_pin Method:
#  Ask user to enter the pin to create a new pin. Also ask user to initialize the balance of your account.
#  change_pin Method:
#  Pin Validation is required before changing the pin. If Pin entered is wrong then message should be displayed “Enter
# correct pin”. if Pin is correct then update the Old Pin with New Pin.
#  check_balance Method:
#  Pin Validation is required for checking the balance. It should display the current balance of account.
#  withdraw Method:
#  Pin Validation is required before withdrawing money. It should ask user for amount to withdraw.  It should also display
# the insufficient fund message if withdraw amount is higher than balance else balance should be updated after withdraw.
#  deposit Method:
#  Pin Validation is required before deposit of money. It should ask user for amount to deposit. balance should be updated
# after deposit.
#  After completion of every method it should ask for choice(menu() method) to perform new operation. If you don’t want
# any operation to perform then you can choose choice of exit to come out from the program
#  9 LJU 202

# %%
class Atm:
    def __init__(self):
        self.pin=None
        self.balance=0
    def create_pin(self):
        p=int(input("Enter the Pin: "))
        b=int(input("Enter the Balance: "))
        self.pin=p
        self.balance=b
    def change_pin(self):
        p1=int(input("Enter the Pin: "))
        if self.pin==p1:
            change=int(input("Enter the Pin: "))
            self.pin=change
            print("Successfully")
        else:
            print("Wrong Entered Pin")
    def check_balance(self):
        p2=int(input("Enter the Pin: "))
        if self.pin==p2:
            print("Balance: ",self.balance)
        else:
            print("Plz try again!!")
    def deposit(self):
        p3=int(input("Enter the Pin: "))
        if self.pin==p3:
            bal=int(input("Enter the deposit balance: "))
            self.balance+=bal
            print("Current balnace: ",self.balance)
        else:
            print("Plz try!!")
    def withdraw(self):
        p4=int(input("Enter the pin: "))
        if self.pin==p4:
            with1=int(input("Enter withdrawl amount: "))
            if with1<=self.balance:
                self.balance-=with1
                print("Current amount: ",self.balance)
        else:
            print("Plz Try!!")
    def menu(self):
        print("-------Menu-------")
        print("1 - Create pin")
        print("2 - Change pin")
        print("3 - check balance")
        print("4 - Deposit")
        print("5 - Withdrawal")
        print("6 - Exit")
        choice=int((input("Enter choice: ")))
        if choice==1:
            self.create_pin()
            self.menu()
        elif choice==2:
            self.change_pin()
            self.menu()
        elif choice==3:
            self.check_balance()
            self.menu()
        elif choice==4:
            self.deposit()
            self.menu()
        elif choice==5:
            self.withdraw()
            self.menu()
        elif choice==6:
            exit()
        else:
            print("Enter valid...")
            self.menu()

# %%
a=Atm()

# %%
a.menu()
# Out:
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 1
# Enter the Pin: 1234
# Enter the Pin: 25000
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 2
# Enter the Pin: 1234
# Enter the Pin: 2345
# Successfully
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 3
# Enter the Pin: 2345
# Balance:  25000
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 4
# Enter the Pin: 2345
# Enter the deposit balance: 2000
# Current balnace:  27000
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 5
# Enter the pin: 2345
# Enter withdrawl amount: 4000
# Current amount:  23000
# -------Menu-------
# 1 - Create pin
# 2 - Change pin
# 3 - check balance
# 4 - Deposit
# 5 - Withdrawal
# 6 - Exit
# Enter choice: 6
