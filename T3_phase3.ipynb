# %% [markdown]
# # Modules and Directories:-- 5 Marks
# **Module**
# - Module is a python file and a collection of statement,variables,functions and classes.
# - It can be written in C / python.
# - There are two types:--
#    1. Inbuilt modules.
#    2. user defind modules.

# %% [markdown]
# ## Inbuilt Module:--

# %%
import math

# %%
math.cos(2*math.pi)

# %%
math.sin(math.pi/2)

# %% [markdown]
# ### Alternate way-import specific methods

# %%
from math import pi,cos

# %%
cos(2*pi)

# %%
sin(pi/2)

# %%
from math import pi,sin

# %%
sin(pi/2)

# %%
cos(2*pi)

# %% [markdown]
# ### creating aliases or alternate names

# %%
from math import cos as cosine,pi as piee

# %%
cosine(2*piee)

# %% [markdown]
# ## Userdefind Modules:

# %% [markdown]
# ###  Create a module

# %%
#1. notepad

# %%
# %%writefile newmodule.py
x=1000
y=[7,8,9]
def fun(z):
    return z

# %% [markdown]
# ###  Import the new module

# %%
import newmodule

# %%
dir(newmodule)

# %%
print(newmodule.x)
print(newmodule.y)
print(newmodule.fun('python'))

# %%
print(x)

# %%
from newmodule import x,y

# %%
print(x)

# %%
from newmodule import x as myvariable

# %%
print(myvariable)
# Out:
# 1000

# %% [markdown]
# # Package:-
# - A Package is a collection of modules.

# %%
# %%writefile pkg/mod1.py
s=[3,4,5]
def hi(x):
    print("mod1 hi")
# Out:
# Overwriting pkg/mod1.py

# %%
# %%writefile pkg/mod2.py
s=[30,40,50]
def hi(x):
    print("mod2 hi")
# Out:
# Writing pkg/mod2.py

# %% [markdown]
# ### Import modules from the package

# %%
import pkg.mod1,pkg.mod2

# %%
pkg.mod1.hi("hello")
# Out:
# mod1 hi

# %%
pkg.mod2.hi("Hello")
# Out:
# mod2 hi

# %%
pkg.mod1.s
# Out:
# [3, 4, 5]

# %%
pkg.mod2.s
# Out:
# [30, 40, 50]

# %% [markdown]
# # 'os' module:-
# - The os module is an inbuilt python module which provides methods for python to interact with
#   the host operating system.

# %%
import os

# %%
os.name
# Out:
# 'nt'

# %%
os.cpu_count()
# Out:
# 4

# %%
os.getcwd()# this method is returns the current working directory.
# Out:
# 'C:\\Users\\LJENG'

# %%
os.mkdir("mydirectory")# this method is create a directory at specified path & argument is provide to path

# %%
os.makedirs("Newdir/subdir")# this method create a new direc. and in new direc. create a sub direc.

# %%
print(os.listdir())# Returns the list of the directiories and subdirectories present.
# Out:
# ['$RECYCLE.BIN', '25002171910023.java', '25002171910023.txt', 'cal.py', 'd2', 'first_word.py', 'img2.jpg', 'img4.jpg', 'img5.jpg', 'Kashyap', 'mymodule.py', 'q3.class', 'Riya', 'shreya', 'System Volume Information', 't2', '__pycache__']

# %%
os.listdir("C:\\Users\\LJENG\\Desktop")
# Out:
# ['desktop.ini', 'Microsoft Edge.lnk', 'Visual Studio 2022.lnk']

# %% [markdown]
# ## chdir(path)
# - it changes the current working dirctry to the specified path.

# %%
os.chdir("D://")

# %%
os.getcwd()
# Out:
# 'D:\\'

# %% [markdown]
# ## Remove directory:-

# %% [markdown]
# ### rmdir(path)
# - The methods remove the directory from the path provided directory should be empty.

# %%
os.rmdir("mydirectory")# no content file should be empty.

# %%
os.rmdir("pkg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-22-d10779d116d8> in <module>
# ----> 1 os.rmdir("pkg")
#
# OSError: [WinError 145] The directory is not empty: 'pkg'

# %%
os.rmdir??

# %% [markdown]
# ## Remove Method:-
# - remove(path)
# - It removes the file at the spcified path.

# %%
os.remove("newmodule.py")# content in the file.

# %%
os.rmdir("remove/r1")

# %%
os.remove("mod1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-5a1d5a44a893> in <module>
# ----> 1 os.remove("mod1")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'mod1'

# %%
# %%writefile string1.py
def stringlength(s):
    count=0
    for i in s:
        if i.isspace():
            continue
        count+=1
    return count
def reverses(s):
    return s[::-1]
# pb:-496
# Out:
# Writing string1.py

# %%
import string1 as s1

# %%
st1=input("Enter: ")
s1.reverses(st1)
# Out:
# Enter: hello python
# 'nohtyp olleh'

# %%
st1=input("Enter: ")
s1.stringlength(st1)
# Out:
# Enter: hello python
# 11

# %%
st1=input("Enter: ")
print(s1.reverses(st1))
print(s1.stringlength(st1))
# Out:
# Enter: hello python
# nohtyp olleh
# 11

# %%
import os#497

# %%
os.makedirs("riya1/newfile")
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\LJENG
# ...

# %%
# %%writefile cal.py
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y
def div(x,y):
    if y==0:
        print("Not divisble")
    return x/y
#pb:--498
# Out:
# Writing cal.py

# %%
import cal as f1

# %%
x=int(input("Enter number: "))
y=int(input("Enter number: "))
print(f1.add(x,y))
print(f1.sub(x,y))
print(f1.mul(x,y))
print(f1.div(x,y))
# Out:
# Enter number: 12
# Enter number: 3
# 15
# 9
# 36
# 4.0

# %%
# %%writefile first_word.py
def fun(s):
    return s.split()[0]
#pb:--499
# Out:
# Overwriting first_word.py

# %%
import first_word as f2

# %%
string1=input("Enter: ")
print(f2.fun(string1))
# Out:
# Enter: hye riya
# hye

# %%
with open("mbox.txt") as a:
    ans=0.0
    count=0
    for i in a:
        for j,k in enumerate(i.split()):
            if k=="X-DSPAM-Confidence:":
                ans+=float(i.split()[j+1])
                print(i.split()[j+1])
                count+=1
    print(count)
    print(ans/count)
# Out:
# 0.8475
# 0.6178
# 0.6961
# 0.7565
# 0.7626
# 0.7556
# 0.7002
# 0.7615
# 0.7601
# 0.7605
# 0.6959
# 0.7606
# 0.7559
# 0.7605
# 0.6932
# 0.7558
# 0.6526
# 0.6948
# 0.6528
# 0.7002
# 0.7554
# 0.6956
# 0.6959
# 0.7556
# 0.9846
# 0.8509
# 0.9907
# 27
# 0.7507185185185187

# %%
pwd
# Out:
# 'D:\\'

# %%
os.chdir(r"C:\Users\LJENG")
